# %% [markdown]
# # 04 Metaheurística GA (VRP)
#
# Esqueleto de algoritmo genético para VRP/CVRP.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
base = Path(r'd:\GitHub\Ruta_aprendizaje_2024\03-aplicación_de_modelos\proyecto_2\data')
df = pd.read_csv(base / 'VRP.csv')
df.columns = df.columns.str.lower()

# %%
customers = list(range(len(df)))
capacity = int(df.get('capacity', pd.Series([1000])).iloc[0])
vehicles = int(df.get('vehicles', pd.Series([3])).iloc[0])
demand = df['demand'].astype(int) if 'demand' in df.columns else np.zeros(len(df), dtype=int)

# %% [markdown]
# ## Población inicial y evaluación (placeholder)

# %%
def random_solution():
    s = customers.copy()
    np.random.shuffle(s)
    return s
def cost(solution):
    return len(solution)
pop = [random_solution() for _ in range(20)]
scores = [cost(s) for s in pop]
min(scores), np.mean(scores)
