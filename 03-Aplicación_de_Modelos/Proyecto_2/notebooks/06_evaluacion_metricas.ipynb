# %% [markdown]
# # 06 Evaluación de Métricas (VRP)
#
# Cálculo de costo total, balanceo y factibilidad.

# %%
import numpy as np
def costo_total(routes):
    return np.random.rand()
def balanceo(routes):
    return np.random.rand()
def factible(routes):
    return True
costo_total([]), balanceo([]), factible([])
