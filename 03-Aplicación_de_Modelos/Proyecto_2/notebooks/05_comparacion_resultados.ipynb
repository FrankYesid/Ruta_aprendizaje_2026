# %% [markdown]
# # 05 Comparación de Resultados
#
# Comparación entre OR-Tools y GA por costo y factibilidad.

# %%
import pandas as pd
df = pd.DataFrame({'modelo':['OR-Tools','GA'],'costo':[0,0],'factible':[True, False]})
df
