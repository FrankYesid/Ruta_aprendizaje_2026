# %% [markdown]
# # 01 Ingesta y Selección de Índices
#
# Carga de dataset y splits desde `docs/`.

# %%
import os
import pandas as pd
from collections import Counter
from src.dataset import parse_index_file, image_path

DATA_ROOT = os.path.join('..', 'data', 'dataset-resized')
DOCS = os.path.join('..', 'docs')
train_entries = parse_index_file(os.path.join(DOCS, 'one-indexed-files-notrash_train.txt'))
val_entries = parse_index_file(os.path.join(DOCS, 'one-indexed-files-notrash_val.txt'))
test_entries = parse_index_file(os.path.join(DOCS, 'one-indexed-files-notrash_test.txt'))
len(train_entries), len(val_entries), len(test_entries)

# %%
Counter([y for _, y in train_entries]), Counter([y for _, y in val_entries]), Counter([y for _, y in test_entries])
