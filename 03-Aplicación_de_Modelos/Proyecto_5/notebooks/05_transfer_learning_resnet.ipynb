# %% [markdown]
# # 05 Transfer Learning con ResNet18

# %%
import os
from src.train_cnn import train_resnet18

DATA_ROOT = os.path.join('..', 'data', 'dataset-resized')
DOCS = os.path.join('..', 'docs')
results = train_resnet18(DATA_ROOT, DOCS, epochs=5, batch_size=32, freeze_backbone=True)
results
