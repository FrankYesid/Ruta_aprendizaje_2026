# %% [markdown]
# # 04 Modelo Baseline CNN

# %%
import os
from src.train_cnn import train_baseline

DATA_ROOT = os.path.join('..', 'data', 'dataset-resized')
DOCS = os.path.join('..', 'docs')
results = train_baseline(DATA_ROOT, DOCS, epochs=5, batch_size=32)
results
