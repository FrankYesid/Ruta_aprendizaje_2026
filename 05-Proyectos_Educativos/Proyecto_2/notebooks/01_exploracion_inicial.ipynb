# %% [markdown]
# # 01 - Exploración Inicial y Diagnóstico de Datos
#
# En este primer reto de limpieza de datos, exploraremos un dataset "sucio" relacionado con las giras musicales más exitosas. El objetivo es identificar problemas comunes como valores nulos, formatos inconsistentes, caracteres especiales y errores de tipografía.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Carga del dataset
data_path = Path("..") / "data" / "my_file (1).csv"
df = pd.read_csv(data_path)

print(f"Dimensiones originales: {df.shape}")
df.head(10)

# %% [markdown]
# ## 1. Identificación de Problemas
#
# Analicemos la estructura y los tipos de datos para detectar inconsistencias.

# %%
# Información general
df.info()

# %%
# Conteo de valores nulos
df.isnull().sum()

# %% [markdown]
# ## 2. Diagnóstico de Columnas Críticas
#
# Observemos los valores únicos y formatos en columnas como `Actual gross` y `Year(s)`.

# %%
print("Muestra de 'Actual gross':")
print(df['Actual gross'].unique()[:10])

print("\nMuestra de 'Year(s)':")
print(df['Year(s)'].unique()[:10])

# %% [markdown]
# ## 3. Lista de Tareas para el Siguiente Cuaderno
#
# 1. Limpiar símbolos de moneda ($) y comas en las columnas de ingresos.
# 2. Tratar las referencias entre corchetes (ej. [1], [a]) en los nombres y valores.
# 3. Normalizar el formato de años (convertir rangos como 2023-2024).
# 4. Manejar valores nulos en columnas de ranking.
